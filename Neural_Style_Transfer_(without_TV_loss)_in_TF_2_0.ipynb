# %% [markdown]
# ## Neural style transfer using TF 2.0 wih `GradientTape`

# %% [markdown]
# The experiments shown here are resource intensive. So it is always better to be on GPU and use it to scale the computations.

# %%
# Install the GPU variant of TF 2.0
# !pip install tensorflow-gpu==2.0.0-alpha0

# %% [markdown]
# ### Regular imports

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.0.0-alpha0

# %%
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.models import Model

import matplotlib.pyplot as plt
import numpy as np
np.random.seed(7)

# %matplotlib inline

# %% [markdown]
# ### The _content_ and the _style_ image

# %%
content = plt.imread('IMG_2483.jpg')
style = plt.imread('hockney.jpg')

# Display the images
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
# Content and style ims side-by-side
ax1.imshow(content)
ax1.set_title('Content Image')
ax2.imshow(style)
ax2.set_title('Style Image')
plt.show()

# %% [markdown]
# ### Helper function to load an image and give it the desired shape

# %%
def load_image(image):
  image = plt.imread(image)
  img = tf.image.convert_image_dtype(image, tf.float32)
  img = tf.image.resize(img, [400, 400])
  # Shape -> (batch_size, h, w, d)
  img = img[tf.newaxis, :]
  return img

# %%
# Finally load in the images 
content = load_image('IMG_2483.jpg')
style = load_image('hockney.jpg')

# %% [markdown]
# ### Pretrained `VGG19` but without the classifier part

# %%
vgg = tf.keras.applications.VGG19(include_top=False, weights='imagenet')
vgg.trainable = False

# %%
# Print the layer names for convenience
for layer in vgg.layers:
  print(layer.name)
# Out:
# input_1
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_conv4
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_conv4
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_conv4
# block5_pool

# %% [markdown]
# ### Specify the layers to get the content and style representations as mentioned in the Paper (Gatys et al. 2016)

# %%
# Content layer 
content_layers = ['block4_conv2'] 

# Style layer 
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1', 
                'block4_conv1', 
                'block5_conv1']


num_content_layers = len(content_layers)
num_style_layers = len(style_layers)

# %% [markdown]
# ### Define a mini VGG network composed of specified layers

# %%
def mini_model(layer_names, model):
  
  outputs = [model.get_layer(name).output for name in layer_names]

  model = Model([vgg.input], outputs)
  return model

# %% [markdown]
# ### Helper function to get the gram matrix for the style loss

# %%
# Gram matrix
def gram_matrix(tensor):
  temp = tensor
  temp = tf.squeeze(temp)
  fun = tf.reshape(temp, [temp.shape[2], temp.shape[0]*temp.shape[1]])
  result = tf.matmul(temp, temp, transpose_b=True)
  gram = tf.expand_dims(result, axis=0)
  return gram

# %% [markdown]
# ### A custom model composed of the style layers and the content layer and custom forward pass

# %%
class Custom_Style_Model(tf.keras.models.Model):
  def __init__(self, style_layers, content_layers):
    super(Custom_Style_Model, self).__init__()
    self.vgg =  mini_model(style_layers + content_layers, vgg)
    self.style_layers = style_layers
    self.content_layers = content_layers
    self.num_style_layers = len(style_layers)
    self.vgg.trainable = False

  def call(self, inputs):
    # Scale back the pixel values
    inputs = inputs*255.0
    # Preprocess them with respect to VGG19 stats
    preprocessed_input = preprocess_input(inputs)
    # Pass through the mini network
    outputs = self.vgg(preprocessed_input)
    # Segregate the style and content representations
    style_outputs, content_outputs = (outputs[:self.num_style_layers], 
                                      outputs[self.num_style_layers:])

    # Calculate the gram matrix for each layer
    style_outputs = [gram_matrix(style_output)
                     for style_output in style_outputs]

    # Assign the content representation and gram matrix in 
    # a layer by layer fashion in dicts
    content_dict = {content_name:value 
                    for content_name, value 
                    in zip(self.content_layers, content_outputs)}

    style_dict = {style_name:value
                  for style_name, value
                  in zip(self.style_layers, style_outputs)}
    
    return {'content':content_dict, 'style':style_dict}

# %% [markdown]
# ### Get the style and content representations

# %%
extractor = Custom_Style_Model(style_layers, content_layers)
style_targets = extractor(style)['style']
content_targets = extractor(content)['content']

# %% [markdown]
# ### Setting up the optimizer and loss function

# %%
opt = tf.optimizers.Adam(learning_rate=0.02)

# %%
# Custom weights for style and content updates
style_weight=100
content_weight=10

# %%
# Custom weights for different style layers
style_weights = {'block1_conv1': 1.,
                 'block2_conv1': 0.8,
                 'block3_conv1': 0.5,
                 'block4_conv1': 0.3,
                 'block5_conv1': 0.1}

# %%
# The loss function to optimize
def total_loss(outputs):
    style_outputs = outputs['style']
    content_outputs = outputs['content']
    style_loss = tf.add_n([style_weights[name]*tf.reduce_mean((style_outputs[name]-style_targets[name])**2) 
                           for name in style_outputs.keys()])
    style_loss *= style_weight / num_style_layers

    content_loss = tf.add_n([tf.reduce_mean((content_outputs[name]-content_targets[name])**2) 
                             for name in content_outputs.keys()])
    content_loss *= content_weight / num_content_layers
    loss = style_loss + content_loss
    return loss

# %% [markdown]
# ### Function to update the target image

# %%
# Decorator to take advantage of AutoGraph
@tf.function()
def train_step(image):
  with tf.GradientTape() as tape:
    outputs = extractor(image)
    loss = total_loss(outputs)

  grad = tape.gradient(loss, image)
  opt.apply_gradients([(grad, image)])
  image.assign(tf.clip_by_value(image, clip_value_min=0.0, clip_value_max=1.0))

# %% [markdown]
# ### Define target image as the original content image

# %%
target_image = tf.Variable(content)

# %% [markdown]
# ### Update the target image iteratively

# %%
epochs = 10
steps_per_epoch = 100

step = 0
for n in range(epochs):
  for m in range(steps_per_epoch):
    step += 1
    train_step(target_image)
  plt.imshow(np.squeeze(target_image.read_value(), 0))
  plt.title("Train step: {}".format(step))
  plt.show()

# %% [markdown]
# The high frequency activations can be smoothened by introducing another loss function - _total variational loss_. The hyperparameters can also be tweaked to get better results.

# %% [markdown]
# ### References:
# - https://www.tensorflow.org/alpha/tutorials/generative/style_transfer
# - [Lesson on Style Transfer from Udacity](https://classroom.udacity.com/courses/ud188#)
# - [Deep Learning for Computer Vision by Adrian Rosebrock (Part II)](https://https://www.pyimagesearch.com/deep-learning-computer-vision-python-book/)
